# %%
import pandas as pd

# %%
raw_episodes = pd.read_csv('../data_example/episodes.csv')

# %%
raw_episodes.describe(include='all')
# Out:
#        episode_id podcast_id      title release_date  duration_seconds
# count          50         50         50           50         50.000000
# unique         50         10         50           47               NaN
# top          ep_1  podcast_1  Episode 1   2023-09-14               NaN
# freq            1          9          1            3               NaN
# mean          NaN        NaN        NaN          NaN       3192.180000
# std           NaN        NaN        NaN          NaN       1430.733759
# min           NaN        NaN        NaN          NaN        348.000000
# 25%           NaN        NaN        NaN          NaN       2057.500000
# 50%           NaN        NaN        NaN          NaN       3424.500000
# 75%           NaN        NaN        NaN          NaN       4362.000000
# max           NaN        NaN        NaN          NaN       5259.000000
